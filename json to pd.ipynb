# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np

# %%
with open('index_2018.json') as f:
    d = json.load(f)

# %%
filling_2018 = json_normalize(d['Filings2018'])

# %%
filling_2018.head(3)
# Out:
#               DLN        EIN FormType          LastUpdated  \
# 0  93493318071517  453578215      990  2018-01-18T23:53:03
# 1  93493318071467  383333202      990  2018-01-18T23:53:03
# 2  93493318071317  233014323      990  2018-01-18T23:53:03
#
#              ObjectId                         OrganizationName SubmittedOn  \
# 0  201713189349307151  MULEY FANATIC FOUNDATION OF WYOMING INC  2018-01-10
# 1  201713189349307146           KALAMAZOO COMMUNITY FOUNDATION  2018-01-10
# 2  201713189349307131                  GOSPEL THROUGH COLOMBIA  2018-01-10
#
#   TaxPeriod                                                URL
# 0    201612  https://s3.amazonaws.com/irs-form-990/20171318...
# 1    201612  https://s3.amazonaws.com/irs-form-990/20171318...
# 2    201612  https://s3.amazonaws.com/irs-form-990/20171318...

# %%
with open('index_2017.json') as f:
    d = json.load(f)

# %%
filling_2017 = json_normalize(d['Filings2017'])

# %%
filling_2017.head(3)
# Out:
#               DLN        EIN FormType          LastUpdated  \
# 0  93493243000066  042662873      990  2017-01-11T22:15:15
# 1  93493243000266  042964630      990  2017-01-11T22:15:15
# 2  93493243003416  382912028      990  2017-01-11T22:15:15
#
#              ObjectId                        OrganizationName SubmittedOn  \
# 0  201612439349300006           ELKS BUILDING CORP OF NORWOOD  2017-01-04
# 1  201612439349300026  NEIGHBORHOOD OF AFFORDABLE HOUSING INC  2017-01-04
# 2  201612439349300341                     RELEAF MICHIGAN INC  2017-01-04
#
#   TaxPeriod                                                URL
# 0    201603  https://s3.amazonaws.com/irs-form-990/20161243...
# 1    201512  https://s3.amazonaws.com/irs-form-990/20161243...
# 2    201512  https://s3.amazonaws.com/irs-form-990/20161243...

# %%
filling_2018.dtypes
# Out:
# DLN                 object
# EIN                 object
# FormType            object
# LastUpdated         object
# ObjectId            object
# OrganizationName    object
# SubmittedOn         object
# TaxPeriod           object
# URL                 object
# dtype: object

# %%
filling_2018['EIN'] = filling_2018['EIN'].astype(np.int64)

# %%
filling_2018.dtypes
# Out:
# DLN                 object
# EIN                  int64
# FormType            object
# LastUpdated         object
# ObjectId            object
# OrganizationName    object
# SubmittedOn         object
# TaxPeriod           object
# URL                 object
# dtype: object

# %%
ntee_filter = pd.read_csv('ntee_filter_BMF.csv')

# %%
ntee_filter.dtypes
# Out:
# EIN              int64
# NAME            object
# STREET          object
# CITY            object
# ZIP             object
# ACTIVITY         int64
# NTEE_CD         object
# REVENUE_AMT    float64
# dtype: object

# %%
ntee_filter.nunique()
# Out:
# EIN            8031
# NAME           7876
# STREET         7290
# CITY            702
# ZIP            7456
# ACTIVITY        520
# NTEE_CD         370
# REVENUE_AMT    2387
# dtype: int64

# %%
ntee_filter.count()
# Out:
# EIN            8031
# NAME           8031
# STREET         8031
# CITY           8031
# ZIP            8031
# ACTIVITY       8031
# NTEE_CD        8031
# REVENUE_AMT    5841
# dtype: int64

# %%
ntee_filter.head(3)
# Out:
#         EIN                                               NAME  \
# 0  10415961                             VETERANS FOR PEACE INC
# 1  10565782                             CHINA TRAINING NETWORK
# 2  10575589  THE UNIVERSAL BUDDHIST CONGREGATION QUANG PHAP...
#
#             STREET         CITY         ZIP   ACTIVITY NTEE_CD  REVENUE_AMT
# 0  1404 N BROADWAY  SAINT LOUIS  63102-2303  123000000    W30Z     553148.0
# 1     PO BOX 11032  SPRINGFIELD  65808-1032          0     X20     138838.0
# 2  5232 BULWER AVE  SAINT LOUIS  63147-3110          0     X50          NaN

# %%
ntee_filter.dtypes
# Out:
# EIN              int64
# NAME            object
# STREET          object
# CITY            object
# ZIP             object
# ACTIVITY         int64
# NTEE_CD         object
# REVENUE_AMT    float64
# dtype: object

# %%
d1_merge = ntee_filter.merge(filling_2018, how='left',left_on='EIN', right_on='EIN')

# %%
d1_merge.head(20)
# Out:
#          EIN                                               NAME  \
# 0   10415961                             VETERANS FOR PEACE INC
# 1   10565782                             CHINA TRAINING NETWORK
# 2   10575589  THE UNIVERSAL BUDDHIST CONGREGATION QUANG PHAP...
# 3   10582036          FO GUANG SHAN SAINT LOUIS BUDDHIST CENTER
# 4   10584486                        ST LOUIS SENIOR DOG PROJECT
# 5   10586306                                   BARCEDA FAMILIES
# 6   10605038             HABITAT FOR HUMANITY INTERNATIONAL INC
# 7   10618842                    TRINITY OUTREACH MINISTRIES INC
# 8   10624838               FAERY TAILS CORGI RESCUE OF ST LOUIS
# 9   10625543                                    BUCKHAWK CENTER
# 10  10643653          AMERICAN ESKIMO RESCUE OF SAINT LOUIS INC
# 11  10643653          AMERICAN ESKIMO RESCUE OF SAINT LOUIS INC
# 12  10643912                                  K-LIFE MINISTRIES
# 13  10657366                                      SOJOURNER INC
# 14  10670203       NEW GENERATIONAL CHRISTIAN CENTER CHURCH INC
# 15  10684355                     FRIENDS OF CARONDELET PARK INC
# 16  10750030                  KINGS SANCTUARY-OUTREACH MINISTRY
# 17  10752303                    LIGHTHOUSE DELIVERANCE MINISTRY
# 18  10756138                          FIVE ACRES ANIMAL SHELTER
# 19  10757598                          CALVARYS GRACE MINISTRIES
#
#                      STREET             CITY         ZIP   ACTIVITY NTEE_CD  \
# 0           1404 N BROADWAY      SAINT LOUIS  63102-2303  123000000    W30Z
# 1              PO BOX 11032      SPRINGFIELD  65808-1032          0     X20
# 2           5232 BULWER AVE      SAINT LOUIS  63147-3110          0     X50
# 3            3109 SMILEY RD        BRIDGETON  63044-3043          0     X50
# 4        7488 RIVERMONT TRL    HOUSE SPRINGS  63051-2033          0     D20
# 5            413 W WATER ST       GREENFIELD  65661-1353          0     P20
# 6                PO BOX 223        CASSVILLE  65625-0223   29380000    L20Z
# 7            565 N WEST BYP      SPRINGFIELD  65802-5349          0     X21
# 8             PO BOX 190816      SAINT LOUIS  63119-6816          0     D20
# 9              1509 CR 437B    MOUNTAIN VIEW  65548-8864          0     D20
# 10            PO BOX 190523      SAINT LOUIS  63119-6523          0     D20
# 11            PO BOX 190523      SAINT LOUIS  63119-6523          0     D20
# 12               PO BOX 701          BOLIVAR  65613-0701    7000000    I21Z
# 13  1410 E KEARNEY ST STE D      SPRINGFIELD  65803-4100          0     X20
# 14   12297 A NATURAL BRIDGE         ST LOUIS  63044-2063          0     X20
# 15            3910 BOWEN ST      SAINT LOUIS  63116-3126          0     N32
# 16         7330 OLIVE ST RD  UNIVERSITY CITY  63130-0000          0     X20
# 17               PO BOX 916        ST ROBERT  65584-0916          0     X20
# 18           1099 PRALLE LN    SAINT CHARLES  63303-5735          0     D20
# 19              PO BOX 1672     POPLAR BLUFF  63902-1672          0     X20
#
#     REVENUE_AMT             DLN FormType          LastUpdated  \
# 0      553148.0  93493319018288      990  2019-02-21T16:25:33
# 1      138838.0             NaN      NaN                  NaN
# 2           NaN             NaN      NaN                  NaN
# 3           NaN             NaN      NaN                  NaN
# 4      140000.0  93492142000328    990EZ  2018-09-12T13:10:49
# 5        5146.0  93492044004388    990EZ  2018-03-14T23:04:38
# 6      116609.0  93492249008188    990EZ  2018-12-22T17:14:37
# 7           NaN             NaN      NaN                  NaN
# 8           0.0             NaN      NaN                  NaN
# 9           0.0             NaN      NaN                  NaN
# 10      56583.0  93492305006397    990EZ  2018-01-18T23:53:03
# 11      56583.0  93492275002318    990EZ  2018-11-15T17:06:31
# 12          NaN             NaN      NaN                  NaN
# 13          NaN             NaN      NaN                  NaN
# 14          NaN             NaN      NaN                  NaN
# 15          0.0             NaN      NaN                  NaN
# 16          NaN             NaN      NaN                  NaN
# 17          NaN             NaN      NaN                  NaN
# 18    1012661.0  93493248005358      990  2018-11-15T17:06:31
# 19          0.0             NaN      NaN                  NaN
#
#               ObjectId                        OrganizationName SubmittedOn  \
# 0   201833199349301828                  VETERANS FOR PEACE INC  2018-12-18
# 1                  NaN                                     NaN         NaN
# 2                  NaN                                     NaN         NaN
# 3                  NaN                                     NaN         NaN
# 4   201821429349200032          SAINT LOUIS SENIOR DOG PROJECT  2018-09-11
# 5   201830449349200438                        BARCEDA FAMILIES  2018-03-05
# 6   201832499349200818     HABITAT FOR HUMANITY OF SOUTH BARRY  2018-11-14
# 7                  NaN                                     NaN         NaN
# 8                  NaN                                     NaN         NaN
# 9                  NaN                                     NaN         NaN
# 10  201743059349200639  AMERICAN ESKIMO RESCUE OF ST LOUIS INC  2018-01-18
# 11  201812759349200231  AMERICAN ESKIMO RESCUE OF ST LOUIS INC  2018-11-08
# 12                 NaN                                     NaN         NaN
# 13                 NaN                                     NaN         NaN
# 14                 NaN                                     NaN         NaN
# 15                 NaN                                     NaN         NaN
# 16                 NaN                                     NaN         NaN
# 17                 NaN                                     NaN         NaN
# 18  201802489349300535               FIVE ACRES ANIMAL SHELTER  2018-10-31
# 19                 NaN                                     NaN         NaN
#
#    TaxPeriod                                                URL
# 0     201712  https://s3.amazonaws.com/irs-form-990/20183319...
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4     201712  https://s3.amazonaws.com/irs-form-990/20182142...
# 5     201706  https://s3.amazonaws.com/irs-form-990/20183044...
# 6     201806  https://s3.amazonaws.com/irs-form-990/20183249...
# 7        NaN                                                NaN
# 8        NaN                                                NaN
# 9        NaN                                                NaN
# 10    201612  https://s3.amazonaws.com/irs-form-990/20174305...
# 11    201712  https://s3.amazonaws.com/irs-form-990/20181275...
# 12       NaN                                                NaN
# 13       NaN                                                NaN
# 14       NaN                                                NaN
# 15       NaN                                                NaN
# 16       NaN                                                NaN
# 17       NaN                                                NaN
# 18    201712  https://s3.amazonaws.com/irs-form-990/20180248...
# 19       NaN                                                NaN

# %%
d1_merge.count()
# Out:
# EIN                 8219
# NAME                8219
# STREET              8219
# CITY                8219
# ZIP                 8219
# ACTIVITY            8219
# NTEE_CD             8219
# REVENUE_AMT         6026
# DLN                 1769
# FormType            1769
# LastUpdated         1769
# ObjectId            1769
# OrganizationName    1769
# SubmittedOn         1769
# TaxPeriod           1769
# URL                 1769
# dtype: int64

# %%
df_final = d1_merge[['EIN','NAME', 'STREET', 'CITY', 'ZIP', 'ACTIVITY','NTEE_CD','URL']]

# %%
df_final[0:10]
# Out:
#         EIN                                               NAME  \
# 0  10415961                             VETERANS FOR PEACE INC
# 1  10565782                             CHINA TRAINING NETWORK
# 2  10575589  THE UNIVERSAL BUDDHIST CONGREGATION QUANG PHAP...
# 3  10582036          FO GUANG SHAN SAINT LOUIS BUDDHIST CENTER
# 4  10584486                        ST LOUIS SENIOR DOG PROJECT
# 5  10586306                                   BARCEDA FAMILIES
# 6  10605038             HABITAT FOR HUMANITY INTERNATIONAL INC
# 7  10618842                    TRINITY OUTREACH MINISTRIES INC
# 8  10624838               FAERY TAILS CORGI RESCUE OF ST LOUIS
# 9  10625543                                    BUCKHAWK CENTER
#
#                STREET           CITY         ZIP   ACTIVITY NTEE_CD  \
# 0     1404 N BROADWAY    SAINT LOUIS  63102-2303  123000000    W30Z
# 1        PO BOX 11032    SPRINGFIELD  65808-1032          0     X20
# 2     5232 BULWER AVE    SAINT LOUIS  63147-3110          0     X50
# 3      3109 SMILEY RD      BRIDGETON  63044-3043          0     X50
# 4  7488 RIVERMONT TRL  HOUSE SPRINGS  63051-2033          0     D20
# 5      413 W WATER ST     GREENFIELD  65661-1353          0     P20
# 6          PO BOX 223      CASSVILLE  65625-0223   29380000    L20Z
# 7      565 N WEST BYP    SPRINGFIELD  65802-5349          0     X21
# 8       PO BOX 190816    SAINT LOUIS  63119-6816          0     D20
# 9        1509 CR 437B  MOUNTAIN VIEW  65548-8864          0     D20
#
#                                                  URL
# 0  https://s3.amazonaws.com/irs-form-990/20183319...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://s3.amazonaws.com/irs-form-990/20182142...
# 5  https://s3.amazonaws.com/irs-form-990/20183044...
# 6  https://s3.amazonaws.com/irs-form-990/20183249...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
df.loc[df['column_name'] == some_value]; 
gapminder_2002 = gapminder[gapminder.year == 2002]; 
is_2002 =  gapminder['year']==2002
 df.query('col1 <= 1 & 1 <= col1')
Out[21]:

# %%
df_final.query("URL == '%https*%'")
# Out:
# Empty DataFrame
# Columns: [EIN, NAME, STREET, CITY, ZIP, ACTIVITY, NTEE_CD, URL]
# Index: []

# %%
df_final[4:7]
# Out:
#         EIN                                    NAME              STREET  \
# 4  10584486             ST LOUIS SENIOR DOG PROJECT  7488 RIVERMONT TRL
# 5  10586306                        BARCEDA FAMILIES      413 W WATER ST
# 6  10605038  HABITAT FOR HUMANITY INTERNATIONAL INC          PO BOX 223
#
#             CITY         ZIP  ACTIVITY NTEE_CD  \
# 4  HOUSE SPRINGS  63051-2033         0     D20
# 5     GREENFIELD  65661-1353         0     P20
# 6      CASSVILLE  65625-0223  29380000    L20Z
#
#                                                  URL
# 4  https://s3.amazonaws.com/irs-form-990/20182142...
# 5  https://s3.amazonaws.com/irs-form-990/20183044...
# 6  https://s3.amazonaws.com/irs-form-990/20183249...

# %%
df_final3 = df_final[4:7]

# %%
df_final3.head()
# Out:
#         EIN                                    NAME              STREET  \
# 4  10584486             ST LOUIS SENIOR DOG PROJECT  7488 RIVERMONT TRL
# 5  10586306                        BARCEDA FAMILIES      413 W WATER ST
# 6  10605038  HABITAT FOR HUMANITY INTERNATIONAL INC          PO BOX 223
#
#             CITY         ZIP  ACTIVITY NTEE_CD  \
# 4  HOUSE SPRINGS  63051-2033         0     D20
# 5     GREENFIELD  65661-1353         0     P20
# 6      CASSVILLE  65625-0223  29380000    L20Z
#
#                                                  URL
# 4  https://s3.amazonaws.com/irs-form-990/20182142...
# 5  https://s3.amazonaws.com/irs-form-990/20183044...
# 6  https://s3.amazonaws.com/irs-form-990/20183249...

# %%
df_final3.to_csv('df_final3')
