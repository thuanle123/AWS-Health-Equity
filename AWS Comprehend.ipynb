# %% [markdown]
# ### Import python Library

# %%
import pandas as pd

# %%
sample_date = pd.read_csv('code-desckey.csv')

# %%
#Feed this data to aws comprehend for training our custom classifer
sample_date.head(10)
# Out:
#    Unnamed: 0        EIN                                              value
# 0           2   20731227  ROTARY IS A SERVICE ORGANIZATION WHOSE MEMBERS...
# 1          26  237085162  CONTINUING EDUCATION CONCERNING CAUSE, CARE AN...
# 2          36  237134308  ROTARY IS AN INTERNATIONAL SERVICE ORGANIZATIO...
# 3          38  237144229  TO PROMOTE MORALITY, IMPART INSTRUCTION, AND G...
# 4          40  237153112  DOMESTIC FRATERNAL ORGANIZATION.CLUB RAISES FU...
# 5          50  237208565  LITTLE PRAIRIE BIBLE CAMP, INC. IS A NON-PROFI...
# 6          63  237277754  SCHOLARSHIPS, CHARITABLE CONTRIBUTIONS TO LOCA...
# 7          66  237301691  PROVIDE ASSISTANCE WITH HEALTH CARE COST FOR T...
# 8          72  237356074  TO ENCOURAGE AN INTEREST IN ROSES, SERVE AS ST...
# 9          73  237356414  PROMOTE HUMANITARIAN & ETHICAL VALUESMEMBERSHI...

# %%
aws_comprehend = pd.read_csv('awscomprehend.csv')

# %%
aws_comprehend[['EIN','value']].head(10)
# Out:
#          EIN                                              value
# 0   20731227  ROTARY IS A SERVICE ORGANIZATION WHOSE MEMBERS...
# 1  237085162  CONTINUING EDUCATION CONCERNING CAUSE, CARE AN...
# 2  237134308  ROTARY IS AN INTERNATIONAL SERVICE ORGANIZATIO...
# 3  237144229  TO PROMOTE MORALITY, IMPART INSTRUCTION, AND G...
# 4  237153112  DOMESTIC FRATERNAL ORGANIZATION.CLUB RAISES FU...
# 5  237208565  LITTLE PRAIRIE BIBLE CAMP, INC. IS A NON-PROFI...
# 6  237277754  SCHOLARSHIPS, CHARITABLE CONTRIBUTIONS TO LOCA...
# 7  237301691  PROVIDE ASSISTANCE WITH HEALTH CARE COST FOR T...
# 8  237356074  TO ENCOURAGE AN INTEREST IN ROSES, SERVE AS ST...
# 9  237356414  PROMOTE HUMANITARIAN & ETHICAL VALUESMEMBERSHI...

# %%
aws_prediction = pd.read_csv('amazon_prediction.csv')

# %%
aws_prediction.head(250)
# Out:
#            EIN CODE  prediction_score
# 0     20731227    D            0.7117
# 1    237085162  O21            0.6395
# 2    237134308  E39            0.3788
# 3    237144229  X40            0.9899
# 4    237153112  P58            0.5437
# 5    237208565  B70            0.8510
# 6    237277754  O51            0.3409
# 7    237301691  P73            0.3177
# 8    237356074  G51            0.5692
# 9    237356414    C            0.5962
# 10   363905358  X90            0.9887
# 11   371074619    D            0.6059
# 12   376057581  X90            0.7755
# 13   430694564  O53            0.6639
# 14   431030299  B50            0.8678
# 15   431075676  R40            0.7711
# 16   431137989  E39            0.4834
# 17   431153138  X22            0.5534
# 18   431154846  B90            0.4323
# 19   431171506  X70            0.8324
# 20   431206890  B21            0.2713
# 21   431218178  P58            0.4963
# 22   431222802  O50            0.9611
# 23   431246752  B29            0.3828
# ...
